# %% [markdown]
# # Convolutional Neural Network (CNN)

# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import os
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = []
labels = []
classes = 43
cur_path = os.getcwd()

# %%
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)

    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((100,100))
            image = np.array(image)
            ###
            image=image/255.0
            ###
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

# %%
data = np.array(data)
labels = np.array(labels)

print(data.shape, labels.shape)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-4-831b67faf862> in <module>
# ----> 1 data = np.array(data)
#       2 labels = np.array(labels)
#       3
#       4 print(data.shape, labels.shape)
#
# MemoryError: Unable to allocate 8.76 GiB for an array with shape (39209, 100, 100, 3) and data type float64

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (31367, 100, 100, 3) (7842, 100, 100, 3) (31367,) (7842,)

# %%
class_names = ['20', '30', '50', '60', '70',
               '80', 'end 80', '100', '120', 'no overtaking', 'no overtaking for trucks', 'crossing', 
              'road with priority', 'give the way', 'STOP', 'stops permitted', 'trucks restricted', 
              'no entry', 'caution', 'mind the left turn', 'mind the right turn', 'many turns',
              'ruts', 'slippery road', 'narrowing', 'road maintenance', 'traffic lights',
               'pedestrians crossing', 'chlidren', 'bicycles', 'ice', 'wild animals', 'end of caution area',
               'turn right', 'turn left', 'go straight', 'go straight or turn right', 
               'go straight or turn left', 'pass by right side', 'pass by left side', 'roundabout',
               'end of no overtaking', 'end of no overtaking for trucks'
              ]

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_test[i]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(43, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 98, 98, 32)        896
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 47, 47, 64)        18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                262208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 43)                2795
# =================================================================
# Total params: 358,251
# Trainable params: 358,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs = 5
history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 981/981 [==============================] - 331s 336ms/step - loss: 2.5356 - accuracy: 0.3160 - val_loss: 0.3886 - val_accuracy: 0.9088
# Epoch 2/5
# 981/981 [==============================] - 323s 329ms/step - loss: 0.6760 - accuracy: 0.7789 - val_loss: 0.1227 - val_accuracy: 0.9770
# Epoch 3/5
# 981/981 [==============================] - 342s 349ms/step - loss: 0.4122 - accuracy: 0.8629 - val_loss: 0.0871 - val_accuracy: 0.9801
# Epoch 4/5
# 981/981 [==============================] - 343s 350ms/step - loss: 0.2961 - accuracy: 0.9005 - val_loss: 0.0553 - val_accuracy: 0.9875
# Epoch 5/5
# 981/981 [==============================] - 328s 334ms/step - loss: 0.2461 - accuracy: 0.9182 - val_loss: 0.0535 - val_accuracy: 0.9897

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
# Out:
# 246/246 - 20s - loss: 0.0535 - accuracy: 0.9897

# %%
print(test_acc)
# Out:
# 0.989670991897583

# %%
model.save("my_model2.h5")
